# %%
import pandas as pd
import numpy as np
import os
import glob
import re
import random
import pickle

# %%
# read in all flights
root = os.getcwd()
data_dir = os.path.join(root, 'instance1')

dfs = []
for file in os.listdir(data_dir):
    if file.startswith('day') and file.endswith('.csv'):
        dfs.append(pd.read_csv(os.path.join(data_dir, file)))
    
df = pd.concat(dfs)
df.columns = df.columns.str.strip()
for col in df.select_dtypes(include=["object"]):
    df[col] = df[col].str.strip()
    
df["#leg_nb"] = df["#leg_nb"].astype(str)
df = df.set_index('#leg_nb')
df["dep_datetime"] = pd.to_datetime(df["date_dep"] + " " + df["hour_dep"])
df["arr_datetime"] = pd.to_datetime(df["date_arr"] + " " + df["hour_arr"])
df['duration'] = (df['arr_datetime'] - df['dep_datetime']).dt.total_seconds() / 3600

# %%
def parse_initial_solution_base2(path):
    pairings = {}

    with open(path, "r") as f:
        text = f.read()

    # Clean wrapper
    text = text.replace("Solution = {", "").replace("};", "").strip()

    # Split into pairing id + content blocks
    raw_entries = re.split(r'\s*Pairing\s+(\d+)\s*:', text)[1:]

    # Loop through [id, content, id, content, ...]
    for i in range(0, len(raw_entries), 2):
        pairing_id = int(raw_entries[i])
        content = raw_entries[i+1].strip()

        # Extract base
        base_match = re.search(r'Base\s+(BASE\d+)\s*:', content)
        base = base_match.group(1) if base_match else None

        # Requirement (1) — only include BASE2
        if base != "BASE2":
            continue

        # Extract legs (including TDH)
        legs = re.findall(r'(?:TDH_)?LEG_\d+_\d+', content)

        # Store in dictionary
        pairings[pairing_id] = {
            "base": base,
            "legs": legs
        }

    return pairings

pairing_dict = parse_initial_solution_base2("instance1/initialSolution.in")

# %%
count = 0

for pairing in pairing_dict:
    flights = pairing_dict[pairing]
    count += len(flights["legs"])

count
# Out:
# 684

# %%
def count_overnights(legs, airlegs_df):
    # Select rows by index directly
    df = airlegs_df.loc[legs].copy()

    # Sort chronologically
    df = df.sort_values('dep_datetime')

    # Overnight = next dep date > current arr date
    overnights = (
        df['dep_datetime'].shift(-1).dt.date >
        df['arr_datetime'].dt.date
    ).sum()

    return int(overnights)

# %%
for idx, pairing in pairing_dict.items():
    pairing_dict[idx]["length"] = len(pairing['legs'])
    # compute duration
    pairing_legs = pairing['legs']
    clean_legs = [leg.replace("TDH_", "") for leg in pairing_legs]
    pairing_dict[idx]["flight_time"] = sum([df.loc[leg]["duration"] for leg in clean_legs])
    pairing_dict[idx]["overnights"] = count_overnights(clean_legs, df)

# %%
def compute_pairing_spans(pairings_dict, legs_df):
    spans = {}

    for pid, pinfo in pairings_dict.items():
        # Normalize leg IDs (remove TDH_)
        clean_legs = [leg.replace("TDH_", "") for leg in pinfo["legs"]]

        # Compute span
        start = min(legs_df.loc[leg, "dep_datetime"] for leg in clean_legs)
        end   = max(legs_df.loc[leg, "arr_datetime"] for leg in clean_legs)

        spans[pid] = (start, end)
        pairing_dict[pid]["start"] = start
        pairing_dict[pid]["end"] = end

    return spans

# %%
with open('pairings.pickle', 'wb') as f:
    pickle.dump(pairing_dict, f)

# %%
spans = compute_pairing_spans(pairing_dict, df)

# %%
with open('spans.pickle', 'wb') as f:
    pickle.dump(spans, f)

# %%
import numpy as np

def compute_weights(pairing_dict, alpha=1, beta=1):
    pids = list(pairing_dict)
    lengths = np.array([pairing_dict[p]["length"] for p in pids], float)
    flights = np.array([pairing_dict[p]["flight_time"] for p in pids], float)

    # normalize
    L = (lengths - lengths.mean()) / (lengths.std() + 1e-6)
    F = (flights - flights.mean()) / (flights.std() + 1e-6)

    weights = {pids[i]: alpha*L[i] + beta*F[i] for i in range(len(pids))}
    return weights

# %%
def make_buckets(pids, weights):
    p_sorted = sorted(pids, key=lambda p: weights[p], reverse=True)
    b1, b2, b3 = [], [], []
    for i, p in enumerate(p_sorted):
        if i % 3 == 0: b1.append(p)
        elif i % 3 == 1: b2.append(p)
        else: b3.append(p)
    b3 = b3[::-1]   # reverse bucket 3 for better balancing
    return b1, b2, b3

# %%
def overlaps(p, q, spans):
    s1, e1 = spans[p]
    s2, e2 = spans[q]
    return not (e1 <= s2 or e2 <= s1)

# %%
def triple_valid(p1, p2, p3, spans):
    return (
        not overlaps(p1,p2,spans) and
        not overlaps(p1,p3,spans) and
        not overlaps(p2,p3,spans)
    )

# %%
def order_by_start(triple, spans):
    return tuple(sorted(triple, key=lambda p: spans[p][0]))

# %%
def pack_balanced_nonoverlapping_triples(pairing_dict, spans, alpha=1, beta=1):
    # compute weights
    weights = compute_weights(pairing_dict, alpha, beta)
    pids = list(pairing_dict)
    
    # sort & bucket
    b1, b2, b3 = make_buckets(pids, weights)
    
    triples = []
    used = set()
    
    # greedy balanced triple pairing
    for p1, p2, p3 in zip(b1, b2, b3):
        if p1 in used or p2 in used or p3 in used:
            continue
        if triple_valid(p1, p2, p3, spans):
            t = (p1, p2, p3)
            t = order_by_start(t, spans)
            triples.append(t)
            used.update([p1, p2, p3])
    
    return triples

# %%
# Improved triple-packing heuristics
# 1) Candidate-based greedy: generate all valid triples from buckets, score by balance & early starts, and greedily pick non-overlapping unique triples.
# 2) Randomized repeated greedy: run the greedy heuristic with random shuffles/weights multiple times and return the best solution.

from itertools import product


def triple_score(triple, weights, spans):
    # Score to prefer balanced weight triples and early-ending triples
    w = [weights[p] for p in triple]
    balance_penalty = abs(w[0]-w[1]) + abs(w[0]-w[2]) + abs(w[1]-w[2])
    # encourage earlier end-times (more spare room for others)
    end_times = [spans[p][1] for p in triple]
    end_penalty = sum([(et - min(end_times)).total_seconds() for et in end_times])
    # negative because lower penalty -> higher score
    return -balance_penalty - 1e-6 * end_penalty


def pack_balanced_nonoverlapping_triples_candidate(pairing_dict, spans, alpha=1, beta=1):
    """Generate all valid triples across 3 buckets, score them, and greedily select disjoint triples.

    This algorithm is O(|b1||b2||b3|) worst-case and finds a better packing than the zip-based approach.
    """
    weights = compute_weights(pairing_dict, alpha, beta)
    pids = list(pairing_dict)
    b1, b2, b3 = make_buckets(pids, weights)

    # Build candidate triples
    candidates = []
    # We'll iterate b1 x b2 x b3, but with pruning when pair overlaps
    for p1 in b1:
        for p2 in b2:
            if overlaps(p1, p2, spans):
                continue
            for p3 in b3:
                if overlaps(p1, p3, spans) or overlaps(p2, p3, spans):
                    continue
                t = (p1, p2, p3)
                score = triple_score(t, weights, spans)
                candidates.append((score, t))

    # Sort by score descending and greedily pick disjoint triples
    candidates.sort(reverse=True, key=lambda s_t: s_t[0])

    used = set()
    triples = []
    for score, t in candidates:
        if t[0] in used or t[1] in used or t[2] in used:
            continue
        triples.append(order_by_start(t, spans))
        used.update(t)

    return triples


def pack_balanced_nonoverlapping_triples_randomized(pairing_dict, spans, alpha=1, beta=1, iterations=500, seed=None):
    """Randomized greedy: shuffle buckets and run greedy candidate-based selection multiple times to find best solution.

    This often helps escape local optima from deterministic ordering.
    """
    if seed is not None:
        random.seed(seed)

    best = []
    weights = compute_weights(pairing_dict, alpha, beta)
    pids = list(pairing_dict)

    for it in range(iterations):
        # shuffle slight ordering inside each bucket to diversify candidate generation
        b1, b2, b3 = make_buckets(pids, weights)
        # introduce tiny random perturbation in order to break ties
        random.shuffle(b1)
        random.shuffle(b2)
        random.shuffle(b3)

        # Build candidate triples with the shuffled buckets; we will stop early if no more
        candidates = []
        for p1 in b1:
            for p2 in b2:
                if overlaps(p1, p2, spans):
                    continue
                for p3 in b3:
                    if overlaps(p1, p3, spans) or overlaps(p2, p3, spans):
                        continue
                    t = (p1, p2, p3)
                    score = triple_score(t, weights, spans) + random.random() * 1e-3
                    candidates.append((score, t))

        random.shuffle(candidates)
        candidates.sort(reverse=True, key=lambda s_t: s_t[0])

        used = set()
        triples = []
        for score, t in candidates:
            if t[0] in used or t[1] in used or t[2] in used:
                continue
            triples.append(order_by_start(t, spans))
            used.update(t)

        if len(triples) > len(best):
            best = triples

    return best

# %%
triples = pack_balanced_nonoverlapping_triples(pairing_dict, spans)

# %%
# Test improved algorithms and compare counts

orig_triples = pack_balanced_nonoverlapping_triples(pairing_dict, spans)
print('Original greedy zip() count:', len(orig_triples))

cand_triples = pack_balanced_nonoverlapping_triples_candidate(pairing_dict, spans)
print('Candidate greedy count:', len(cand_triples))

rand_triples = pack_balanced_nonoverlapping_triples_randomized(pairing_dict, spans, iterations=200, seed=1234)
print('Randomized greedy best count (200 iters):', len(rand_triples))

# Show a few sample triples if available
for name, tset in [('orig', orig_triples), ('cand', cand_triples), ('rand', rand_triples)]:
    print('\n', name.upper(), 'triples sample (first 5):')
    for t in tset[:5]:
        wsum = sum(compute_weights(pairing_dict)[p] for p in t)
        print(t, 'weight-sum=%.3f' % wsum)

# %%
def assert_no_airleg_overlap(legs, airlegs_df):
    """
    Raises an error if ANY air legs in `legs` overlap in time.
    
    Parameters
    ----------
    legs : list of leg IDs (strings)
    airlegs_df : pandas DataFrame indexed by leg_id with columns:
        - dep_datetime (datetime64)
        - arr_datetime (datetime64)
    """
    
    # Extract only the relevant legs
    df = airlegs_df.loc[legs].copy()
    
    # Sort by departure time
    df = df.sort_values("dep_datetime")
    
    # Iterate pairwise
    for i in range(len(df) - 1):
        current_end = df.iloc[i]["arr_datetime"]
        next_start = df.iloc[i+1]["dep_datetime"]
        
        if current_end > next_start:
            raise ValueError(
                f"Overlap detected between legs "
                f"{df.index[i]} (ends {current_end}) and "
                f"{df.index[i+1]} (starts {next_start})."
            )
    
    # If no overlap:
    return True

# %%
lines = {}
for idx, triple in enumerate(triples):
    lines[idx] = {}
    legs = []
    flight_time = 0
    overnights = 0
    for pairing in triple:
        pairing_legs = pairing_dict[pairing]["legs"]
        clean_legs = [leg.replace("TDH_", "") for leg in pairing_legs]
        legs += clean_legs
        flight_time += pairing_dict[pairing]["flight_time"]
        overnights += pairing_dict[pairing]["overnights"]
    assert assert_no_airleg_overlap(legs, df)
    lines[idx]["legs"] = legs
    lines[idx]["num_legs"] = len(legs)
    lines[idx]["overnights"] = overnights
    lines[idx]["flight_time"] = flight_time

# %%
lines
# Out:
# {0: {'legs': ['LEG_01_21',
#    'LEG_01_4',
#    'LEG_01_32',
#    'LEG_02_10',
#    'LEG_02_11',
#    'LEG_02_19',
#    'LEG_02_23',
#    'LEG_03_22',
#    'LEG_03_14',
#    'LEG_04_35',
#    'LEG_11_29',
#    'LEG_11_24',
#    'LEG_26_24',
#    'LEG_26_25',
#    'LEG_26_28',
#    'LEG_27_14',
#    'LEG_27_10',
#    'LEG_27_17',
#    'LEG_27_21',
#    'LEG_28_20',
#    'LEG_28_14',
#    'LEG_28_10'],
#   'num_legs': 22,
#   'overnights': 2,
#   'flight_time': np.float64(44.300000000000004)},
#  1: {'legs': ['LEG_03_3',
#    'LEG_03_2',
#    'LEG_14_27',
#    'LEG_14_17',
#    'LEG_14_18',
#    'LEG_15_14',
#    'LEG_15_13',
#    'LEG_15_22',
#    'LEG_16_20',
#    'LEG_16_15',
#    'LEG_16_16',
#    'LEG_16_6',
#    'LEG_26_26',
#    'LEG_26_3',
#    'LEG_27_1',
#    'LEG_27_2',
#    'LEG_27_7',
#    'LEG_28_21',
#    'LEG_28_23',
#    'LEG_28_5',
#    'LEG_28_29',
#    'LEG_29_26'],
#   'num_legs': 22,
#   'overnights': 3,
#   'flight_time': np.float64(41.8)},
#  2: {'legs': ['LEG_08_14',
#    'LEG_09_35',
#    'LEG_10_1',
#    'LEG_10_34',
#    'LEG_10_33',
#    'LEG_11_10',
#    'LEG_11_11',
#    'LEG_11_19',
#    'LEG_12_20',
#    'LEG_13_19',
#    'LEG_13_3',
#    'LEG_13_31',
#    'LEG_15_1',
#    'LEG_15_32',
#    'LEG_15_31',
#    'LEG_16_11',
#    'LEG_16_12',
#    'LEG_16_21',
#    'LEG_16_25',
#    'LEG_17_24',
#    'LEG_17_29',
#    'LEG_17_4'],
#   'num_legs': 22,
#   'overnights': 2,
#   'flight_time': np.float64(40.81666666666667)},
#  3: {'legs': ['LEG_07_29',
#    'LEG_07_24',
#    'LEG_08_25',
#    'LEG_08_27',
#    'LEG_08_21',
#    'LEG_08_4',
#    'LEG_08_5',
#    'LEG_09_7',
#    'LEG_09_6',
#    'LEG_09_8',
#    'LEG_09_29',
#    'LEG_09_24',
#    'LEG_10_25',
#    'LEG_10_27',
#    'LEG_10_21',
#    'LEG_10_4',
#    'LEG_10_5',
#    'LEG_11_7',
#    'LEG_11_6',
#    'LEG_11_8',
#    'LEG_22_10',
#    'LEG_23_33'],
#   'num_legs': 22,
#   'overnights': 1,
#   'flight_time': np.float64(39.11666666666666)},
#  4: {'legs': ['LEG_03_29',
#    'LEG_03_24',
#    'LEG_04_25',
#    'LEG_04_27',
#    'LEG_04_21',
#    'LEG_04_4',
#    'LEG_04_5',
#    'LEG_05_5',
#    'LEG_05_4',
#    'LEG_05_6',
#    'LEG_06_26',
#    'LEG_06_21',
#    'LEG_07_25',
#    'LEG_07_27',
#    'LEG_07_21',
#    'LEG_07_4',
#    'LEG_07_5',
#    'LEG_08_7',
#    'LEG_08_6',
#    'LEG_08_8',
#    'LEG_21_9',
#    'LEG_22_33'],
#   'num_legs': 22,
#   'overnights': 1,
#   'flight_time': np.float64(39.11666666666666)},
#  5: {'legs': ['LEG_13_28',
#    'LEG_13_2',
#    'LEG_13_30',
#    'LEG_14_11',
#    'LEG_14_12',
#    'LEG_14_20',
#    'LEG_15_20',
#    'LEG_15_15',
#    'LEG_22_29',
#    'LEG_22_4',
#    'LEG_22_31',
#    'LEG_23_11',
#    'LEG_23_12',
#    'LEG_23_21',
#    'LEG_24_20',
#    'LEG_24_15',
#    'LEG_24_10',
#    'LEG_25_33'],
#   'num_legs': 18,
#   'overnights': 3,
#   'flight_time': np.float64(36.75)},
#  6: {'legs': ['LEG_03_25',
#    'LEG_03_27',
#    'LEG_03_21',
#    'LEG_03_4',
#    'LEG_03_5',
#    'LEG_04_7',
#    'LEG_04_6',
#    'LEG_04_8',
#    'LEG_17_10',
#    'LEG_18_33',
#    'LEG_20_24',
#    'LEG_20_4',
#    'LEG_20_27',
#    'LEG_21_10',
#    'LEG_21_11',
#    'LEG_22_15',
#    'LEG_22_16',
#    'LEG_22_6'],
#   'num_legs': 18,
#   'overnights': 2,
#   'flight_time': np.float64(34.63333333333333)},
#  7: {'legs': ['LEG_01_31',
#    'LEG_01_2',
#    'LEG_01_3',
#    'LEG_01_33',
#    'LEG_01_5',
#    'LEG_02_7',
#    'LEG_02_6',
#    'LEG_02_8',
#    'LEG_22_27',
#    'LEG_22_28',
#    'LEG_22_1',
#    'LEG_22_32',
#    'LEG_22_5',
#    'LEG_23_8',
#    'LEG_23_7',
#    'LEG_23_9',
#    'LEG_27_11',
#    'LEG_28_9'],
#   'num_legs': 18,
#   'overnights': 0,
#   'flight_time': np.float64(26.3)},
#  8: {'legs': ['LEG_01_6',
#    'LEG_01_8',
#    'LEG_01_9',
#    'LEG_02_32',
#    'LEG_02_30',
#    'LEG_02_28',
#    'LEG_09_31',
#    'LEG_09_0',
#    'LEG_09_1',
#    'LEG_09_34',
#    'LEG_09_5',
#    'LEG_10_7',
#    'LEG_10_6',
#    'LEG_10_8',
#    'LEG_31_2',
#    'LEG_31_29'],
#   'num_legs': 16,
#   'overnights': 1,
#   'flight_time': np.float64(30.549999999999997)},
#  9: {'legs': ['LEG_03_30',
#    'LEG_03_28',
#    'LEG_10_29',
#    'LEG_10_24',
#    'LEG_11_25',
#    'LEG_11_27',
#    'LEG_11_21',
#    'LEG_11_4',
#    'LEG_27_5',
#    'LEG_27_4',
#    'LEG_27_26',
#    'LEG_28_16',
#    'LEG_28_17',
#    'LEG_28_19'],
#   'num_legs': 14,
#   'overnights': 1,
#   'flight_time': np.float64(26.416666666666664)},
#  10: {'legs': ['LEG_04_30',
#    'LEG_04_28',
#    'LEG_21_28',
#    'LEG_21_4',
#    'LEG_21_5',
#    'LEG_22_8',
#    'LEG_22_7',
#    'LEG_22_9',
#    'LEG_24_29',
#    'LEG_24_4',
#    'LEG_24_5',
#    'LEG_25_8',
#    'LEG_25_7',
#    'LEG_25_9'],
#   'num_legs': 14,
#   'overnights': 0,
#   'flight_time': np.float64(25.68333333333333)},
#  11: {'legs': ['LEG_01_30',
#    'LEG_01_28',
#    'LEG_20_13',
#    'LEG_20_0',
#    'LEG_21_0',
#    'LEG_21_1',
#    'LEG_21_29',
#    'LEG_21_2',
#    'LEG_27_6',
#    'LEG_28_12',
#    'LEG_28_13',
#    'LEG_28_2',
#    'LEG_28_30'],
#   'num_legs': 13,
#   'overnights': 1,
#   'flight_time': np.float64(26.53333333333333)},
#  12: {'legs': ['LEG_10_3',
#    'LEG_10_2',
#    'LEG_10_31',
#    'LEG_10_0',
#    'LEG_28_3',
#    'LEG_29_19',
#    'LEG_29_21',
#    'LEG_29_5',
#    'LEG_30_3',
#    'LEG_31_19',
#    'LEG_31_12',
#    'LEG_31_10'],
#   'num_legs': 12,
#   'overnights': 2,
#   'flight_time': np.float64(23.333333333333336)},
#  13: {'legs': ['LEG_02_3',
#    'LEG_02_2',
#    'LEG_02_31',
#    'LEG_02_0',
#    'LEG_29_2',
#    'LEG_29_29',
#    'LEG_29_28',
#    'LEG_30_26',
#    'LEG_30_2',
#    'LEG_30_29',
#    'LEG_30_28',
#    'LEG_31_26'],
#   'num_legs': 12,
#   'overnights': 2,
#   'flight_time': np.float64(18.616666666666667)},
#  14: {'legs': ['LEG_15_3',
#    'LEG_15_2',
#    'LEG_15_30',
#    'LEG_15_0',
#    'LEG_24_3',
#    'LEG_24_2',
#    'LEG_24_30',
#    'LEG_24_0',
#    'LEG_25_3',
#    'LEG_25_2',
#    'LEG_25_30',
#    'LEG_25_0'],
#   'num_legs': 12,
#   'overnights': 0,
#   'flight_time': np.float64(15.350000000000001)},
#  15: {'legs': ['LEG_11_3',
#    'LEG_11_2',
#    'LEG_11_31',
#    'LEG_11_0',
#    'LEG_16_3',
#    'LEG_16_2',
#    'LEG_16_30',
#    'LEG_16_0',
#    'LEG_19_2',
#    'LEG_19_1',
#    'LEG_19_27',
#    'LEG_19_0'],
#   'num_legs': 12,
#   'overnights': 0,
#   'flight_time': np.float64(15.350000000000001)},
#  16: {'legs': ['LEG_04_3',
#    'LEG_04_2',
#    'LEG_04_31',
#    'LEG_04_0',
#    'LEG_18_3',
#    'LEG_18_2',
#    'LEG_18_29',
#    'LEG_18_4',
#    'LEG_22_3',
#    'LEG_22_2',
#    'LEG_22_30',
#    'LEG_22_0'],
#   'num_legs': 12,
#   'overnights': 0,
#   'flight_time': np.float64(16.35)},
#  17: {'legs': ['LEG_12_22',
#    'LEG_12_24',
#    'LEG_12_18',
#    'LEG_12_3',
#    'LEG_23_3',
#    'LEG_23_2',
#    'LEG_23_30',
#    'LEG_23_0',
#    'LEG_26_2',
#    'LEG_26_1',
#    'LEG_26_27',
#    'LEG_26_0'],
#   'num_legs': 12,
#   'overnights': 0,
#   'flight_time': np.float64(18.21666666666667)},
#  18: {'legs': ['LEG_05_2',
#    'LEG_05_1',
#    'LEG_05_27',
#    'LEG_05_0',
#    'LEG_18_27',
#    'LEG_18_28',
#    'LEG_18_16',
#    'LEG_18_6',
#    'LEG_29_3',
#    'LEG_30_19',
#    'LEG_30_21',
#    'LEG_30_5'],
#   'num_legs': 12,
#   'overnights': 1,
#   'flight_time': np.float64(18.866666666666667)},
#  19: {'legs': ['LEG_04_1',
#    'LEG_04_34',
#    'LEG_04_33',
#    'LEG_05_7',
#    'LEG_06_1',
#    'LEG_06_12',
#    'LEG_07_30',
#    'LEG_07_28',
#    'LEG_19_26',
#    'LEG_19_25'],
#   'num_legs': 10,
#   'overnights': 1,
#   'flight_time': np.float64(21.3)},
#  20: {'legs': ['LEG_13_27',
#    'LEG_13_25',
#    'LEG_15_29',
#    'LEG_15_4',
#    'LEG_15_5',
#    'LEG_16_8',
#    'LEG_16_7',
#    'LEG_16_9',
#    'LEG_20_26',
#    'LEG_20_25'],
#   'num_legs': 10,
#   'overnights': 0,
#   'flight_time': np.float64(21.316666666666666)},
#  21: {'legs': ['LEG_06_27',
#    'LEG_06_25',
#    'LEG_12_4',
#    'LEG_12_6',
#    'LEG_27_25',
#    'LEG_27_24',
#    'LEG_27_15',
#    'LEG_28_0',
#    'LEG_28_24',
#    'LEG_28_25',
#    'LEG_28_4'],
#   'num_legs': 11,
#   'overnights': 0,
#   'flight_time': np.float64(22.166666666666668)},
#  22: {'legs': ['LEG_17_30',
#    'LEG_17_0',
#    'LEG_17_1',
#    'LEG_17_32',
#    'LEG_17_5',
#    'LEG_18_8',
#    'LEG_18_7',
#    'LEG_18_9',
#    'LEG_28_8',
#    'LEG_29_9',
#    'LEG_29_8',
#    'LEG_30_9'],
#   'num_legs': 12,
#   'overnights': 0,
#   'flight_time': np.float64(18.483333333333334)},
#  23: {'legs': ['LEG_01_14',
#    'LEG_02_35',
#    'LEG_13_22',
#    'LEG_13_24',
#    'LEG_13_29',
#    'LEG_13_0',
#    'LEG_14_0',
#    'LEG_14_1',
#    'LEG_14_32',
#    'LEG_14_4',
#    'LEG_30_8',
#    'LEG_31_9'],
#   'num_legs': 12,
#   'overnights': 1,
#   'flight_time': np.float64(22.200000000000003)},
#  24: {'legs': ['LEG_02_25',
#    'LEG_02_27',
#    'LEG_02_21',
#    'LEG_02_4',
#    'LEG_02_5',
#    'LEG_03_7',
#    'LEG_03_6',
#    'LEG_03_8',
#    'LEG_14_15',
#    'LEG_15_33',
#    'LEG_15_10',
#    'LEG_16_33'],
#   'num_legs': 12,
#   'overnights': 2,
#   'flight_time': np.float64(23.03333333333333)},
#  25: {'legs': ['LEG_11_14',
#    'LEG_12_30',
#    'LEG_16_10',
#    'LEG_17_33',
#    'LEG_19_24',
#    'LEG_19_10',
#    'LEG_20_12',
#    'LEG_20_1',
#    'LEG_20_17',
#    'LEG_20_3',
#    'LEG_21_30',
#    'LEG_21_7',
#    'LEG_21_8'],
#   'num_legs': 13,
#   'overnights': 3,
#   'flight_time': np.float64(23.083333333333336)},
#  26: {'legs': ['LEG_09_14',
#    'LEG_10_35',
#    'LEG_13_26',
#    'LEG_13_21',
#    'LEG_14_26',
#    'LEG_14_28',
#    'LEG_14_22',
#    'LEG_14_6',
#    'LEG_14_7',
#    'LEG_15_8',
#    'LEG_15_7',
#    'LEG_15_9',
#    'LEG_25_10',
#    'LEG_26_29'],
#   'num_legs': 14,
#   'overnights': 2,
#   'flight_time': np.float64(25.18333333333333)},
#  27: {'legs': ['LEG_05_18',
#    'LEG_05_3',
#    'LEG_06_22',
#    'LEG_06_24',
#    'LEG_06_18',
#    'LEG_06_4',
#    'LEG_06_5',
#    'LEG_07_7',
#    'LEG_07_6',
#    'LEG_07_8',
#    'LEG_10_14',
#    'LEG_11_35',
#    'LEG_23_10',
#    'LEG_24_33'],
#   'num_legs': 14,
#   'overnights': 3,
#   'flight_time': np.float64(25.5)},
#  28: {'legs': ['LEG_17_3',
#    'LEG_17_2',
#    'LEG_18_10',
#    'LEG_19_29',
#    'LEG_19_19',
#    'LEG_19_14',
#    'LEG_19_15',
#    'LEG_20_9',
#    'LEG_20_8',
#    'LEG_20_20',
#    'LEG_21_19',
#    'LEG_21_14',
#    'LEG_21_15',
#    'LEG_21_6'],
#   'num_legs': 14,
#   'overnights': 1,
#   'flight_time': np.float64(26.449999999999996)},
#  29: {'legs': ['LEG_02_1',
#    'LEG_02_34',
#    'LEG_02_33',
#    'LEG_03_10',
#    'LEG_03_11',
#    'LEG_03_19',
#    'LEG_03_23',
#    'LEG_04_22',
#    'LEG_04_14',
#    'LEG_05_30',
#    'LEG_08_3',
#    'LEG_08_2',
#    'LEG_12_2',
#    'LEG_12_1'],
#   'num_legs': 14,
#   'overnights': 1,
#   'flight_time': np.float64(27.499999999999996)},
#  30: {'legs': ['LEG_02_29',
#    'LEG_02_24',
#    'LEG_08_1',
#    'LEG_08_34',
#    'LEG_08_33',
#    'LEG_09_10',
#    'LEG_09_11',
#    'LEG_10_15',
#    'LEG_10_9',
#    'LEG_11_32',
#    'LEG_11_30',
#    'LEG_11_28',
#    'LEG_17_17',
#    'LEG_17_26'],
#   'num_legs': 14,
#   'overnights': 2,
#   'flight_time': np.float64(25.666666666666668)},
#  31: {'legs': ['LEG_16_17',
#    'LEG_16_26',
#    'LEG_16_1',
#    'LEG_16_32',
#    'LEG_16_31',
#    'LEG_17_11',
#    'LEG_17_12',
#    'LEG_17_21',
#    'LEG_18_20',
#    'LEG_18_15',
#    'LEG_18_5',
#    'LEG_19_4',
#    'LEG_19_3',
#    'LEG_19_5',
#    'LEG_24_17',
#    'LEG_24_26'],
#   'num_legs': 16,
#   'overnights': 1,
#   'flight_time': np.float64(27.116666666666674)},
#  32: {'legs': ['LEG_06_23',
#    'LEG_06_13',
#    'LEG_06_14',
#    'LEG_07_13',
#    'LEG_07_12',
#    'LEG_07_20',
#    'LEG_08_18',
#    'LEG_08_15',
#    'LEG_08_9',
#    'LEG_09_32',
#    'LEG_09_30',
#    'LEG_09_28',
#    'LEG_21_16',
#    'LEG_21_25',
#    'LEG_25_17',
#    'LEG_25_26'],
#   'num_legs': 16,
#   'overnights': 1,
#   'flight_time': np.float64(29.65)},
#  33: {'legs': ['LEG_23_17',
#    'LEG_23_26',
#    'LEG_26_12',
#    'LEG_26_23',
#    'LEG_27_26',
#    'LEG_27_8',
#    'LEG_27_23',
#    'LEG_28_11',
#    'LEG_28_27',
#    'LEG_28_6',
#    'LEG_28_7',
#    'LEG_28_15',
#    'LEG_28_22',
#    'LEG_29_18',
#    'LEG_29_20',
#    'LEG_30_18',
#    'LEG_30_12',
#    'LEG_30_10'],
#   'num_legs': 18,
#   'overnights': 1,
#   'flight_time': np.float64(26.900000000000002)},
#  34: {'legs': ['LEG_21_3',
#    'LEG_21_32',
#    'LEG_21_31',
#    'LEG_22_11',
#    'LEG_22_12',
#    'LEG_22_21',
#    'LEG_22_25',
#    'LEG_23_24',
#    'LEG_23_29',
#    'LEG_23_4',
#    'LEG_23_5',
#    'LEG_24_8',
#    'LEG_24_7',
#    'LEG_24_9',
#    'LEG_29_27',
#    'LEG_29_14',
#    'LEG_31_27',
#    'LEG_31_14'],
#   'num_legs': 18,
#   'overnights': 0,
#   'flight_time': np.float64(29.266666666666666)}}

# %%
with open("lines.pickle", "wb") as f: # 'wb' for write binary
    pickle.dump(lines, f)
